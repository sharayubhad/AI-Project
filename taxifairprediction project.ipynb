# %% [markdown]
# # AIM :Can you predict a rider's taxi fare?

# %% [markdown]
# importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.model_selection import train_test_split

# %% [markdown]
# loading dataset

# %%
taxi_df = pd.read_csv('/content/drive/MyDrive/TaxiFare.csv')
taxi_df
# Out:
#       unique_id  amount      date_time_of_pickup  longitude_of_pickup  \
# 0       26:21.0     4.5  2009-06-15 17:26:21 UTC           -73.844311
# 1       52:16.0    16.9  2010-01-05 16:52:16 UTC           -74.016048
# 2       35:00.0     5.7  2011-08-18 00:35:00 UTC           -73.982738
# 3       30:42.0     7.7  2012-04-21 04:30:42 UTC           -73.987130
# 4       51:00.0     5.3  2010-03-09 07:51:00 UTC           -73.968095
# ...         ...     ...                      ...                  ...
# 49995   25:15.0    15.0  2013-06-12 23:25:15 UTC           -73.999973
# 49996   19:18.0     7.5  2015-06-22 17:19:18 UTC           -73.984756
# 49997   53:00.0     6.9  2011-01-30 04:53:00 UTC           -74.002698
# 49998   09:00.0     4.5  2012-11-06 07:09:00 UTC           -73.946062
# 49999   13:14.0    10.9  2010-01-13 08:13:14 UTC           -73.932603
#
#        latitude_of_pickup  longitude_of_dropoff  latitude_of_dropoff  \
# 0               40.721319            -73.841610            40.712278
# 1               40.711303            -73.979268            40.782004
# 2               40.761270            -73.991242            40.750562
# 3               40.733143            -73.991567            40.758092
# 4               40.768008            -73.956655            40.783762
# ...                   ...                   ...                  ...
# 49995           40.748531            -74.016899            40.705993
# 49996           40.768211            -73.987366            40.760597
# 49997           40.739428            -73.998108            40.759483
# 49998           40.777567            -73.953450            40.779687
# 49999           40.763805            -73.932603            40.763805
#
#        no_of_passenger
# 0                    1
# 1                    1
# 2                    2
# 3                    1
# 4                    1
# ...                ...
# 49995                1
# 49996                1
# 49997                1
# 49998                2
# 49999                1
#
# [50000 rows x 8 columns]

# %% [markdown]
# checking dataset

# %%
taxi_df.head(10)
# Out:
#   unique_id  amount      date_time_of_pickup  longitude_of_pickup  \
# 0   26:21.0     4.5  2009-06-15 17:26:21 UTC           -73.844311
# 1   52:16.0    16.9  2010-01-05 16:52:16 UTC           -74.016048
# 2   35:00.0     5.7  2011-08-18 00:35:00 UTC           -73.982738
# 3   30:42.0     7.7  2012-04-21 04:30:42 UTC           -73.987130
# 4   51:00.0     5.3  2010-03-09 07:51:00 UTC           -73.968095
# 5   50:45.0    12.1  2011-01-06 09:50:45 UTC           -74.000964
# 6   35:00.0     7.5  2012-11-20 20:35:00 UTC           -73.980002
# 7   22:00.0    16.5  2012-01-04 17:22:00 UTC           -73.951300
# 8   10:00.0     9.0  2012-12-03 13:10:00 UTC           -74.006462
# 9   11:00.0     8.9  2009-09-02 01:11:00 UTC           -73.980658
#
#    latitude_of_pickup  longitude_of_dropoff  latitude_of_dropoff  \
# 0           40.721319            -73.841610            40.712278
# 1           40.711303            -73.979268            40.782004
# 2           40.761270            -73.991242            40.750562
# 3           40.733143            -73.991567            40.758092
# 4           40.768008            -73.956655            40.783762
# 5           40.731630            -73.972892            40.758233
# 6           40.751662            -73.973802            40.764842
# 7           40.774138            -73.990095            40.751048
# 8           40.726713            -73.993078            40.731628
# 9           40.733873            -73.991540            40.758138
#
#    no_of_passenger
# 0                1
# 1                1
# 2                2
# 3                1
# 4                1
# 5                1
# 6                1
# 7                1
# 8                1
# 9                2

# %%
taxi_df.shape
# Out:
# (50000, 8)

# %%
taxi_df.describe()
# Out:
#              amount  longitude_of_pickup  latitude_of_pickup  \
# count  50000.000000         50000.000000        50000.000000
# mean      11.364171           -72.509756           39.933759
# std        9.685557            10.393860            6.224857
# min       -5.000000           -75.423848          -74.006893
# 25%        6.000000           -73.992062           40.734880
# 50%        8.500000           -73.981840           40.752678
# 75%       12.500000           -73.967148           40.767360
# max      200.000000            40.783472          401.083332
#
#        longitude_of_dropoff  latitude_of_dropoff  no_of_passenger
# count          50000.000000         50000.000000     50000.000000
# mean             -72.504616            39.926251         1.667840
# std               10.407570             6.014737         1.289195
# min              -84.654241           -74.006377         0.000000
# 25%              -73.991152            40.734372         1.000000
# 50%              -73.980082            40.753372         1.000000
# 75%              -73.963584            40.768167         2.000000
# max               40.851027            43.415190         6.000000

# %%
taxi_df.sample(15)
# Out:
#       unique_id  amount      date_time_of_pickup  longitude_of_pickup  \
# 43150   24:00.0   13.30  2012-06-09 19:24:00 UTC           -73.980985
# 10002   26:01.0    0.00  2010-02-15 14:26:01 UTC           -73.987115
# 13357   53:00.0    9.50  2014-11-04 15:53:00 UTC           -73.973662
# 41344   45:00.0   12.00  2014-12-17 14:45:00 UTC           -73.995498
# 6494    28:24.0    8.90  2011-02-15 16:28:24 UTC           -73.975329
# 4453    49:00.0    7.70  2009-10-05 20:49:00 UTC           -73.978470
# 32275   49:00.0    4.90  2011-07-17 10:49:00 UTC           -73.963380
# 45100   49:00.0   32.27  2010-11-22 16:49:00 UTC           -73.953513
# 15451   01:26.0    4.10  2010-11-08 09:01:26 UTC           -73.985070
# 23835   06:00.0    6.50  2010-08-14 01:06:00 UTC           -73.991447
# 45540   20:15.0    5.50  2013-05-13 07:20:15 UTC           -73.994280
# 38671   52:00.0    3.70  2012-02-03 14:52:00 UTC           -73.982533
# 16601   12:34.0    6.90  2011-09-07 23:12:34 UTC           -73.991181
# 4018    09:00.0    9.50  2013-01-23 17:09:00 UTC           -73.957392
# 12937   14:47.0   10.90  2012-05-18 09:14:47 UTC           -73.982978
#
#        latitude_of_pickup  longitude_of_dropoff  latitude_of_dropoff  \
# 43150           40.733422            -74.001650            40.761177
# 10002           40.738808            -74.005911            40.713960
# 13357           40.764135            -73.987187            40.749297
# 41344           40.739148            -73.982543            40.727455
# 6494            40.762502            -73.987845            40.738445
# 4453            40.745020            -73.959115            40.764083
# 32275           40.793627            -73.951210            40.785907
# 45100           40.775358            -73.872600            40.774400
# 15451           40.747994            -73.991789            40.738264
# 23835           40.726860            -74.000183            40.742825
# 45540           40.750141            -73.985504            40.760480
# 38671           40.771647            -73.987762            40.767117
# 16601           40.749852            -73.987392            40.756031
# 4018            40.770547            -73.974647            40.753902
# 12937           40.739739            -73.978243            40.762940
#
#        no_of_passenger
# 43150                1
# 10002                1
# 13357                1
# 41344                1
# 6494                 1
# 4453                 1
# 32275                2
# 45100                2
# 15451                1
# 23835                1
# 45540                1
# 38671                1
# 16601                2
# 4018                 6
# 12937                1

# %%
taxi_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   unique_id             50000 non-null  object
#  1   amount                50000 non-null  float64
#  2   date_time_of_pickup   50000 non-null  object
#  3   longitude_of_pickup   50000 non-null  float64
#  4   latitude_of_pickup    50000 non-null  float64
#  5   longitude_of_dropoff  50000 non-null  float64
#  6   latitude_of_dropoff   50000 non-null  float64
#  7   no_of_passenger       50000 non-null  int64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 3.1+ MB

# %% [markdown]
# data cleaning

# %%
taxi_df.isnull().sum()
# Out:
# amount                  0
# longitude_of_pickup     0
# latitude_of_pickup      0
# longitude_of_dropoff    0
# latitude_of_dropoff     0
# no_of_passenger         0
# dtype: int64

# %%
taxi_df.head(20)
# Out:
#     amount  longitude_of_pickup  latitude_of_pickup  longitude_of_dropoff  \
# 0      4.5           -73.844311           40.721319            -73.841610
# 1     16.9           -74.016048           40.711303            -73.979268
# 2      5.7           -73.982738           40.761270            -73.991242
# 3      7.7           -73.987130           40.733143            -73.991567
# 4      5.3           -73.968095           40.768008            -73.956655
# 5     12.1           -74.000964           40.731630            -73.972892
# 6      7.5           -73.980002           40.751662            -73.973802
# 7     16.5           -73.951300           40.774138            -73.990095
# 8      9.0           -74.006462           40.726713            -73.993078
# 9      8.9           -73.980658           40.733873            -73.991540
# 10     5.3           -73.996335           40.737142            -73.980721
# 11     5.5             0.000000            0.000000              0.000000
# 12     4.1           -73.991601           40.744712            -73.983081
# 13     7.0           -74.005360           40.728867            -74.008913
# 14     7.7           -74.001821           40.737547            -73.998060
# 15     5.0             0.000000            0.000000              0.000000
# 16    12.5           -73.986430           40.760465            -73.988990
# 17     5.3           -73.981060           40.737690            -73.994177
# 18     5.3           -73.969505           40.784843            -73.958732
# 19     4.0           -73.979815           40.751902            -73.979446
#
#     latitude_of_dropoff  no_of_passenger
# 0             40.712278                1
# 1             40.782004                1
# 2             40.750562                2
# 3             40.758092                1
# 4             40.783762                1
# 5             40.758233                1
# 6             40.764842                1
# 7             40.751048                1
# 8             40.731628                1
# 9             40.758138                2
# 10            40.733559                1
# 11             0.000000                3
# 12            40.744682                2
# 13            40.710907                1
# 14            40.722788                2
# 15             0.000000                1
# 16            40.737075                1
# 17            40.728412                1
# 18            40.783357                1
# 19            40.755481                1

# %% [markdown]
# we found that there are no null values but still having zeroes in it

# %%
mean2 = taxi_df["longitude_of_pickup"].mean()
taxi_df["longitude_of_pickup"] = taxi_df["longitude_of_pickup"].replace(np.nan,mean2)

# %%
mean3 = taxi_df["latitude_of_pickup"].mean()
taxi_df["latitude_of_pickup"] = taxi_df["latitude_of_pickup"].replace(np.nan,mean3)

# %%
mean4 = taxi_df["longitude_of_dropoff"].mean()
taxi_df["longitude_of_dropoff"] = taxi_df["longitude_of_dropoff"].replace(np.nan,mean4)

# %%
mean5 = taxi_df["latitude_of_dropoff"].mean()
taxi_df["latitude_of_dropoff"] = taxi_df["latitude_of_dropoff"].replace(np.nan,mean5)

# %%
taxi_df.head(15)
# Out:
#    unique_id  amount      date_time_of_pickup  longitude_of_pickup  \
# 0    26:21.0     4.5  2009-06-15 17:26:21 UTC           -73.844311
# 1    52:16.0    16.9  2010-01-05 16:52:16 UTC           -74.016048
# 2    35:00.0     5.7  2011-08-18 00:35:00 UTC           -73.982738
# 3    30:42.0     7.7  2012-04-21 04:30:42 UTC           -73.987130
# 4    51:00.0     5.3  2010-03-09 07:51:00 UTC           -73.968095
# 5    50:45.0    12.1  2011-01-06 09:50:45 UTC           -74.000964
# 6    35:00.0     7.5  2012-11-20 20:35:00 UTC           -73.980002
# 7    22:00.0    16.5  2012-01-04 17:22:00 UTC           -73.951300
# 8    10:00.0     9.0  2012-12-03 13:10:00 UTC           -74.006462
# 9    11:00.0     8.9  2009-09-02 01:11:00 UTC           -73.980658
# 10   30:50.0     5.3  2012-04-08 07:30:50 UTC           -73.996335
# 11   24:00.0     5.5  2012-12-24 11:24:00 UTC             0.000000
# 12   04:03.0     4.1  2009-11-06 01:04:03 UTC           -73.991601
# 13   54:00.0     7.0  2013-07-02 19:54:00 UTC           -74.005360
# 14   11:05.0     7.7  2011-04-05 17:11:05 UTC           -74.001821
#
#     latitude_of_pickup  longitude_of_dropoff  latitude_of_dropoff  \
# 0            40.721319            -73.841610            40.712278
# 1            40.711303            -73.979268            40.782004
# 2            40.761270            -73.991242            40.750562
# 3            40.733143            -73.991567            40.758092
# 4            40.768008            -73.956655            40.783762
# 5            40.731630            -73.972892            40.758233
# 6            40.751662            -73.973802            40.764842
# 7            40.774138            -73.990095            40.751048
# 8            40.726713            -73.993078            40.731628
# 9            40.733873            -73.991540            40.758138
# 10           40.737142            -73.980721            40.733559
# 11            0.000000              0.000000             0.000000
# 12           40.744712            -73.983081            40.744682
# 13           40.728867            -74.008913            40.710907
# 14           40.737547            -73.998060            40.722788
#
#     no_of_passenger
# 0                 1
# 1                 1
# 2                 2
# 3                 1
# 4                 1
# 5                 1
# 6                 1
# 7                 1
# 8                 1
# 9                 2
# 10                1
# 11                3
# 12                2
# 13                1
# 14                2

# %%
 taxi_df.drop(['date_time_of_pickup'],axis=1,inplace=True)

# %%
taxi_df.drop(['unique_id'],axis=1,inplace=True)

# %%
taxi_df.sample(10)
# Out:
#        amount  longitude_of_pickup  latitude_of_pickup  longitude_of_dropoff  \
# 16449     6.5           -73.996848           40.744625            -73.983682
# 32788     7.3           -73.978026           40.758765            -73.982267
# 11240     6.9           -73.962051           40.779048            -73.984576
# 5607      5.0           -74.001460           40.746791            -74.001096
# 39917    10.0           -73.962458           40.758778            -73.976708
# 39753    16.0           -73.998351           40.723081            -73.970788
# 15987    12.1           -73.954018           40.770768            -73.982878
# 45854    13.0           -73.973972           40.743082            -73.985453
# 6416      6.1           -73.137393           41.366138            -73.137393
# 38641    14.0           -73.983275           40.741347            -73.992920
#
#        latitude_of_dropoff  no_of_passenger
# 16449            40.744735                3
# 32788            40.771015                2
# 11240            40.776826                1
# 5607             40.739932                1
# 39917            40.732443                4
# 39753            40.766963                2
# 15987            40.727030                2
# 45854            40.752627                1
# 6416             41.366138                1
# 38641            40.729952                1

# %% [markdown]
# modals implementation

# %%
x = taxi_df.drop(columns=['amount'],axis=1)
y = taxi_df['amount']

# %%
x_train, x_test, y_train,y_test = train_test_split(x, y, test_size=0.3, random_state=1)

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
model_1 = GradientBoostingRegressor()

# %%
model_1.fit(x_train,y_train)
# Out:
# GradientBoostingRegressor()

# %%
s1 = model_1.score(x_train,y_train)
print("After GradientBoostingRegressor train score are: ",s1)
# Out:
# After GradientBoostingRegressor train score are:  0.7441405403638608

# %%
s1 = model_1.score(x_test,y_test)
print("After GradientBoostingRegressor train score are: ",s1)
# Out:
# After GradientBoostingRegressor train score are:  0.6914475533046602

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
model_2 = DecisionTreeRegressor()

# %%
model_2.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
s2 = model_2.score(x_train,y_train)
print("After Decision TreeRegressor train score are: ",s2)
# Out:
# After Decision TreeRegressor train score are:  0.9763906952071122

# %%
s2 = model_2.score(x_test,y_test)
print("After Decision TreeRegressor train score are: ",s2)
# Out:
# After Decision TreeRegressor train score are:  0.519322607866394

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model_3 = RandomForestRegressor()

# %%
model_3.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
s3 = model_3.score(x_train,y_train)
print("After RandomForestRegressor train score are: ",s3)
# Out:
# After RandomForestRegressor train score are:  0.9440432801793134

# %%
s3 = model_3.score(x_test,y_test)
print("After RandomForestRegressor train score are: ",s3)
# Out:
# After RandomForestRegressor train score are:  0.7393166325501512
